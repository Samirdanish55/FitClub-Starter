# %% [markdown]
# <a href="https://colab.research.google.com/github/Samirdanish55/FitClub-Starter/blob/master/Complete_Data_Analysis_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# -----------------------------
# Load Data
# -----------------------------
df = pd.read_csv('/content/sales_data.csv')

# -----------------------------
# Explore Data
# -----------------------------
print("Shape:", df.shape)
print("Columns:", df.columns)
print(df.dtypes)

# -----------------------------
# Clean Data
# -----------------------------
df.fillna(0, inplace=True)
df.drop_duplicates(inplace=True)

# -----------------------------
# Analysis
# -----------------------------
total_revenue = df['Total_Sales'].sum()
average_sales = df['Total_Sales'].mean()

product_sales = df.groupby('Product')['Total_Sales'].sum()
best_product = product_sales.idxmax()

# -----------------------------
# Report
# -----------------------------
print("\n===== SALES REPORT =====")
print(f"Total Revenue: ₹{total_revenue:,.2f}")
print(f"Average Sales: ₹{average_sales:,.2f}")
print(f"Best-Selling Product: {best_product}")

# -----------------------------
# Visualization
# -----------------------------

# Bar Chart
product_sales.plot(kind='bar', title='Revenue by Product')
plt.ylabel('Revenue')
plt.show()

# Line Chart
df.groupby('Date')['Total_Sales'].sum().plot(kind='line', title='Sales Trend Over Time')
plt.ylabel('Revenue')
plt.show()
# Out:
# Shape: (100, 7)
# Columns: Index(['Date', 'Product', 'Quantity', 'Price', 'Customer_ID', 'Region',
#        'Total_Sales'],
#       dtype='object')
# Date           object
# Product        object
# Quantity        int64
# Price           int64
# Customer_ID    object
# Region         object
# Total_Sales     int64
# dtype: object
#
# ===== SALES REPORT =====
# Total Revenue: ₹12,365,048.00
# Average Sales: ₹123,650.48
# Best-Selling Product: Laptop
