# %% [markdown]
# <a href="https://colab.research.google.com/github/Samirdanish55/FitClub-Starter/blob/master/personal_introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Personal Introduction Program

# Asking for user inputs
name = input("Enter your name: ")
age = input("Enter your age: ")
hobby = input("Enter your favorite hobby: ")

# Displaying the welcome message
print("\n--- Welcome Message ---")
print(f"Hello {name}! 👋")
print(f"You are {age} years old and you love {hobby}.")
print("Nice to meet you! 😊")
# Out:
# Enter your name: Samir
# Enter your age: 45
# Enter your favorite hobby: Cricket
#
# --- Welcome Message ---
# Hello Samir! 👋
# You are 45 years old and you love Cricket.
# Nice to meet you! 😊
